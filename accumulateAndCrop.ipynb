# %%
import rasterio
import dask.array as da
from dask_rasterio import read_raster, write_raster
import os
import fnmatch
import numpy as np
import geopandas as gpd
import shapely
from rasterio.warp import calculate_default_transform, reproject, Resampling
import earthpy.spatial as es
import seaborn as sns
import matplotlib.pyplot as plt
import earthpy.plot as ep
import imageio

# %%
def projectRaster(raster_fn, raster_src, projected_dir, dst_crs):
    transform, width, height = calculate_default_transform(
            raster_src.crs, dst_crs, raster_src.width, raster_src.height, *raster_src.bounds)
    kwargs = raster_src.meta.copy()
    kwargs.update({
        'crs': dst_crs,
        'transform': transform,
        'width': width,
        'height': height
    })

    projected_raster = projected_dir + '\\' + raster_fn.split("\\")[-1]
    with rasterio.open(projected_raster, 'w', **kwargs) as dst:
        for i in range(1, raster_src.count + 1):
            reproject(
                source=rasterio.band(raster_src, i),
                destination=rasterio.band(dst, i),
                src_transform=raster_src.transform,
                src_crs=raster_src.crs,
                dst_transform=transform,
                dst_crs=dst_crs,
                resampling=Resampling.nearest)
    return projected_raster, kwargs

# %%
def crop_raster(src, crop_shp):
    cropped_raster, cropped_meta = es.crop_image(src, crop_shp)
    array = cropped_raster
    array[array==0] = np.nan    
    array[array==9999] = np.nan
    return array, cropped_meta

# %%
def cropRasterByMask(src_projected, crop_shp, cropped_raster_fn):
    geom = []
    coord = shapely.geometry.mapping(crop_shp)["features"][0]["geometry"]
    geom.append(coord)

    out_image, out_transform = rasterio.mask.mask(src_projected, geom, crop=True)
    out_meta = src_projected.meta
    out_meta.update({"driver": "GTiff",
                    "height": out_image.shape[1],
                    "width": out_image.shape[2],
                    "transform": out_transform})

    with rasterio.open(os.path.join(cropped_raster_fn), "w", **out_meta) as dest:
        dest.write(out_image)

# %%
input_dir = r'Z:\LWI_StageIV\Hurricane Katrina 2005'
output_dir= r'Z:\LWI_StageIV\!Accumulated'
crop_shp = gpd.read_file(r"Z:\GIS\StageIv Boundary.shp")
dst_crs = 'EPSG:4326' 
projected_dir = os.path.join(input_dir, 'projected')
cropped_dir = os.path.join(input_dir, 'cropped')

# Assumes Directory Name is the name of the storm and wanted name of the output files.
# I.e: input_dir=r'Z:\LWI_StageIV\Hurricane Cindy 2005' ==> output file will be 'Hurricane Cindy 2005.tif'
outputFilename = input_dir.split('\\')[-1]+'-cropped.tif'

# Check if output, projected, and cropped directories exist.
isExist = os.path.exists(output_dir)
if not isExist:
        os.makedirs(output_dir)
isExist = os.path.exists(projected_dir)
if not isExist:
        os.makedirs(projected_dir)
isExist = os.path.exists(cropped_dir)
if not isExist:
        os.makedirs(cropped_dir)

# get all files with extension .01h (the default pattern for uncompressed 1hr precip data from UCAR EOL).
# Script is not accounting for potential naming patterns for AK and PR.
merge_dir=[]
for filename in fnmatch.filter(os.listdir(input_dir),'*.01h'): 
    merge_dir.append((os.path.join(input_dir, filename)))

merge_dir.sort()

map2array=[]
for raster in merge_dir:
    print(f'projecting and cropping {raster}. Then adding to dask array list: map2array')
    src = rasterio.open(raster)
    projected_raster, kwargs = projectRaster(raster, src, projected_dir, dst_crs)
    src_projected = rasterio.open(projected_raster)
    # array, cropped_meta = crop_raster(src, crop_shp)
    # Write Cropped Raster to Disk
    cropped_raster_fn = cropped_dir + '\\' + raster.split("\\")[-1]
    cropRasterByMask(src_projected, crop_shp, cropped_raster_fn)
    cropped_src = rasterio.open(cropped_raster_fn)
    profile = cropped_src.profile
    array = cropped_src.read(1)
    array[array==0] = np.nan    
01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090421.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090422.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090423.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090500.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090501.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090502.01h. Then adding to dask array list: map2array
# ...
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090616.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090617.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090618.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090619.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090620.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090621.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090622.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090623.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090700.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090701.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090702.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090703.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090704.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090705.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090706.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090707.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090708.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090709.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090710.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090711.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090712.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090713.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090714.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090715.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090716.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090717.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090718.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090719.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090720.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090721.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090722.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090723.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090800.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090801.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090802.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090803.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090804.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090805.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090806.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090807.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090808.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090809.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090810.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090811.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090812.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090813.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090814.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090815.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090816.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090817.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090818.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090819.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090820.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090821.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090822.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090823.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090900.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090901.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090902.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090903.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090904.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090905.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090906.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090907.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090908.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090909.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090910.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090911.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090912.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090913.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090914.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090915.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090916.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090917.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090918.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090919.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090920.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090921.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090922.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005090923.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091000.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091001.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091002.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091003.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091004.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091005.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091006.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091007.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091008.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091009.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091010.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091011.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091012.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091013.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091014.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091015.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091016.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091017.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091018.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091019.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091020.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091021.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091022.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091023.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091100.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091101.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091102.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091103.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091104.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091105.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091106.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091107.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091108.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091109.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091110.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091111.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091112.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091113.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091114.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091115.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091116.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091117.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091118.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091119.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091120.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091121.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091122.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091123.01h. Then adding to dask array list: map2array
# projecting and cropping Z:\LWI_StageIV\Hurricane Katrina 2005\ST4.2005091200.01h. Then adding to dask array list: map2array

# %%
ds_stack = da.stack(map2array)

# with rasterio.open(merge_dir[0]) as src:
#     profile=src.profile
#     profile.update(compress='lzw')
print (f'writing Raster to {output_dir}\\{outputFilename}')
write_raster(f'{output_dir}\\{outputFilename}', da.nansum(ds_stack,0), **profile)
# write_raster(f'{output_dir}\\{outputFilename}', da.nansum(ds_stack,0))
# Out:
# writing Raster to Z:\LWI_StageIV\!Accumulated\Hurricane Katrina 2005-cropped.tif

# %%
raster_fn = r'Z:\LWI_StageIV\test\ST4.2005082000.01h'
crop_shp = gpd.read_file(r"Z:\GIS\StageIv Boundary.shp")
dst_crs = 'EPSG:4326' 
input_dir = r'Z:\LWI_StageIV\test'
projected_dir = os.path.join(input_dir, 'projected')

src = rasterio.open(raster_fn)
projected_raster, kwargs = projectRaster(raster_fn, src, projected_dir, dst_crs)
src_projected = rasterio.open(projected_raster)
# array, cropped_meta = crop_raster(src, crop_shp)
# Write Cropped Raster to Disk
# cropped_raster_fn = cropped_dir + '\\' + raster.split("\\")[-1]
# with rasterio.open(cropped_raster_fn, 'w', **kwargs) as dest:
#     dest.write(array.squeeze().astype(rasterio.uint8), 1)
#     profile = dest.profile
# map2array.append(da.from_array(array, chunks=array.shape))

# src.close()
# src_projected.close()

# %%
fig, ax = plt.subplots(figsize=(15, 15))
la = gpd.read_file("Z:\GIS\Louisiana.shp")
bbox = la.total_bounds
la_extent=bbox[[0,2,1,3]]

bbox_lwi = crop_shp.total_bounds
lwi_extent = bbox_lwi[[0,2,1,3]]
fn = raster_fn
title = fn.split('\\')[-1]
raster = src_projected

# raster.window?
raster_window = raster.window(*bbox_lwi)
array = raster.read(1, window=raster_window)
array[array==raster.nodata] = np.nan
im = plt.imshow(array, extent=lwi_extent, cmap='rainbow')
cb = plt.colorbar(im, shrink=.6)
ax.set(title=f"{title} Cumulative Precip (mm)")
ax.set_axis_off()
la.boundary.plot(ax=plt.gca(), color='darkgrey')

# %%
import shapely
geom = []
coord = shapely.geometry.mapping(crop_shp)["features"][0]["geometry"]
geom.append(coord)

out_image, out_transform = rasterio.mask.mask(src_projected, geom, crop=True)
out_meta = src_projected.meta
out_meta.update({"driver": "GTiff",
                 "height": out_image.shape[1],
                 "width": out_image.shape[2],
                 "transform": out_transform})

with rasterio.open("test.tif", "w", **out_meta) as dest:
    dest.write(out_image)
